# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
week = pd.Series({'Понедельник': 90, 
                  'Вторник': 76, 
                  'Среда': 51, 
                  'Четверг': 39, 
                  'Пятница': 21, 
                  'Суббота': 33, 
                  'Воскресенье': 86})

# %%
plt.figure(figsize=(20, 5))
plt.plot(week)
plt.title("124")
plt.show()
